# %%
# %pylab inline 
# %load_ext autoreload
# %autoreload 2
import pandas as pd

import sys
sys.path.insert(0, 'code')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
from pycantus import Cantus
Cantus.load()
chant = Cantus.get_chant('97603bf6175683c41f278f3891fb002cc6152379c0d6699afdbe0a48fe0331e0')

# %%
chant.show()
# Out:
#         <style type="text/css">
#             .chant {
#                 border: 1px solid #ccc;
#                 border-radius:5px;
#                 padding: 1em;
#                 position: relative;
#             }
#             .details {
#                 margin-bottom: 1em;
#             }
#             .value {
#                 margin-right: 1em;
#             }
#             .prop {
#                 color: #999;
#             }
#             .incipit {
#                 font-weight: bold;
#                 margin-bottom: .5em;
#             }
#             .chant-id {
#                 font-size: .8em;
#                 color: #666;
#                 margin-top: .5em;
#             }
#         </style>
#         <div class="chant">
#                 <div class="details">
#                     <p class="incipit">Statuit dominus supra petram pedes</p>
#                     <span class="prop">cantus_id</span> <span class="value">007698</span><span class="prop">feast</span> <span class="value">Feria 3 per annum</span><span class="prop">office</span> <span class="value">M</span><span class="prop">genre</span> <span class="value">Responsory</span><span class="prop">position</span> <span class="value">1.2</span><span class="prop">mode</span> <span class="value">1</span>
#                     <a href="http://cantus.uwaterloo.ca/chant/254172/" target="_blank">View online</a>
#                 </div><style type="text/css">
#             .parsed-chant {
#                 line-height: 1;
#                 position: relative;
#             }
#             .section {
#                 display: inline;
#             }
#             .section.boundary {
#                 display: inline-block;
#                 border: 0;
#                 border-bottom: 1px dashed black;
#                 margin-bottom: 1em;
#             }
#             .volpiano {
#                 font-family: volpiano;
#                 font-size: 2.5em;
#             }
#             .word, .syllable, .neume {
#                 display: inline-block;
#             }
#             .word {
#                 height: 5em;
#                 margin: .75em 0;
#             }
#             .word.boundary {
#                 border-left: 1px solid #00c;
#                 border-right: 1px solid #00c;
#             }
#             .syllable.boundary {
#                 border-color: #c00;
#             }
#             .neume.boundary {
#                 border-color: #fff;
#                 border-width: 5px;
#                 margin: 0px;
#                 padding-right: 1px;
#                 border-left:0;
#             }
#             .text {
#                 position: absolute;
#                 margin-top: 1em;
#                 background: #fff;
#             }
#             .boundary {
#                 padding-right: 3px;
#                 padding-left: 1px;
#                 margin: 0 4px;
#                 border-left: 1px solid #999;
#                 border-right: 1px solid #999;
#             }
#             .section.incomplete {
#                 color: hsl(10, 30%, 40%);
#             }
#             word.incomplete {
#                 color: hsl(10, 50%, 40%);
#             }
#             .syllable.incomplete {
#                 color: hsl(10, 100%, 40%);
#             }
#             .syllable.incomplete .volpiano {
#                 background: hsl(10, 50%, 95%);
#             }
#             p.status {
#                 font-weight:normal;
#                 color: #e88;
#             }
#             </style>
#         <div class="parsed-chant" style="font-size:14px"><div class=" section"><div class="word "><div class="syllable ">
#                     <div class="volpiano ">1-</div>
#                     <div class="text text-empty"></div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">dhj--</div></div>
#                     <div class="text ">sta-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">h--</div></div>
#                     <div class="text ">tu-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">h---</div></div>
#                     <div class="text ">it</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">hkhjk--</div></div>
#                     <div class="text ">do-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">h--</div></div>
#                     <div class="text ">mi-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">hg-</div><div class="neume ">hjh---</div></div>
#                     <div class="text ">nus</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">f--</div></div>
#                     <div class="text ">su-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">g---</div></div>
#                     <div class="text ">pra</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">gh-</div><div class="neume ">kh7--</div></div>
#                     <div class="text ">pe-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">ghg---</div></div>
#                     <div class="text ">tram</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">fgfed--</div></div>
#                     <div class="text ">pe-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">cd---</div></div>
#                     <div class="text ">des</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">de-</div><div class="neume ">fef--</div></div>
#                     <div class="text ">me-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">ed---</div></div>
#                     <div class="text ">os</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">d---</div></div>
#                     <div class="text ">et</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">d--</div></div>
#                     <div class="text ">di-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">fgh--</div></div>
#                     <div class="text ">re-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">g---</div></div>
#                     <div class="text ">xit</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">g--</div></div>
#                     <div class="text ">gres-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">g---</div></div>
#                     <div class="text ">sus</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">gfg--</div></div>
#                     <div class="text ">me-</div>
#                 </div><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">fgfed---</div></div>
#                     <div class="text ">os</div>
#                 </div></div><div class="word "><div class="syllable ">
#                     <div class="volpiano "><div class="neume ">fgfe--</div></div>
#                     <div class="text ">de-</div>

# %%
chant.play()
# Out:
#                 <div id='midiPlayerDiv1642'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1642');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
